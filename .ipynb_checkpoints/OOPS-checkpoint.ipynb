# %% [raw]
# Abstraction in Python is a fundamental concept of object-oriented programming that allows you to hide complex implementation details and expose only the necessary parts of an object. It helps simplify code and makes it easier to manage.

# %%
class Vehicle(ABC):
    def start_engine(self):
        pass
    def stop_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started."

    def stop_engine(self):
        return "Car engine stopped."

class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started."

    def stop_engine(self):
        return "Motorcycle engine stopped."


def vehicle_action(vehicle: Vehicle):
    print(vehicle.start_engine())
    print(vehicle.stop_engine())

car = Car()
motorcycle = Motorcycle()


vehicle_action(car)        
vehicle_action(motorcycle)
# Out:
# Car engine started.
# Car engine stopped.
# Motorcycle engine started.
# Motorcycle engine stopped.

# %% [raw]
# Encapsulation is one of the key principles of object-oriented programming. It restricts access to certain components of an object and only exposes a controlled interface. This helps protect the integrity of the data and ensures that it can only be manipulated in safe ways.

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.__salary = salary  

    def set_salary(self, new_salary):
        if new_salary >= 0:
            self.__salary = new_salary
            return f"Salary updated to ${self.__salary}."
        return "Invalid salary amount."

    def get_salary(self):
        return f"Salary for {self.name}: ${self.__salary}."


employee = Employee("karan", 50000)

print(employee.get_salary())      .
print(employee.set_salary(55000))  
print(employee.get_salary())
# Out:
# Salary for karan: $50000.
# Salary updated to $55000.
# Salary for karan: $55000.

# %% [raw]
# Inheritance is a key feature of object-oriented programming that allows one class  to inherit attributes and methods from another class . This promotes code reuse and establishes a hierarchical relationship between classes.

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

    def honk(self):
        return "Honk!"


class Car(Vehicle):
    def honk(self):
        return "Car honks!"


class Bike(Vehicle):
    def honk(self):
        return "Bike honks!"


car = Car("Toyota")
bike = Bike("Yamaha")

print(f"{car.brand}: {car.honk()}")  
print(f"{bike.brand}: {bike.honk()}")
# Out:
# Toyota: Car honks!
# Yamaha: Bike honks!

# %% [raw]
# Polymorphism is a core concept in object-oriented programming that allows methods to do different things based on the object that it is acting upon. It enables objects of different classes to be treated as objects of a common superclass.

# %%
class Animal:
    def speak(self):
        return "Some sound"

class Dog(Animal):
    def speak(self):
        return "Bark"

class Cat(Animal):
    def speak(self):
        return "Meow"


def animal_sound(animal):
    print(animal.speak())

dog = Dog()
cat = Cat()

animal_sound(dog)  
animal_sound(cat)
# Out:
# Bark
# Meow

# %%
class shape():
    def area(self):
        pass

class  rectangle(shape):
    def __init__(self,lenght,breadth):
        self.lenght = lenght
        self.breadth = breadth

    def area(self):
        return self.lenght*self.breadth

r1 = rectangle(5,6)
print(r1.area())
# Out:
# 30

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}")

class Student(Person):
    def __init__(self, name, age, Id, standard):
        super().__init__(name, age)
        self.Id = Id
        self.standard = standard

    def display_student(self):
        print(f"Student ID: {self.Id}, Standard: {self.standard}")

s1 = Student("Karan", 21, 457657, "12th")
s1.display()  # Display person details
s1.display_student()  # Display student details
# Out:
# Name: Karan, Age: 21
# Student ID: 457657, Standard: 12th

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age =age
    def display(self):
        print(f"Name:{self.name},Age:{self.age}")

class student(person):
    def __init__(self,name,age,Id,standard):
        super().__init__(name,age)
        self.Id = Id
        self.standard = standard

def display_student(self):
        print(f"Student ID:{self.id},Standard:{self.standard}")

s1 = student("karan",21,457657,"12th")
s1.display_student()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 18
#      15         print(f"Student ID:{self.id},Standard:{self.standard}")
#      17 s1 = student("karan",21,457657,"12th")
# ---> 18 s1.display_student()
#
# AttributeError: 'student' object has no attribute 'display_student'

# %%
import speech_recognition as sr
import pyttsx3
import requests
import time
import os

# Initialize text-to-speech engine
def speak(text):
    engine = pyttsx3.init()
    engine.say(text)
    engine.runAndWait()

# Listen for commands from the microphone
def listen_for_commands():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio)
            print(f"You said: {command}")
            return command
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            return None
        except sr.RequestError:
            print("Could not request results from Google Speech Recognition service.")
            return None

# Function to ask a question using OpenAI API
def ask_question(question):
    api_key = os.getenv("AIzaSyBmL73D2QDdlnkrDTzLuMQbbRYGccaIapc")  # Load API key from environment variable
    headers = {
        'Authorization': f'Bearer {api_key}',
        'Content-Type': 'application/json'
    }
    data = {
        'model': 'gpt-3.5-turbo',
        'messages': [{'role': 'user', 'content': question}]
    }
    
    try:
        response = requests.post('https://api.openai.com/v1/chat/completions', headers=headers, json=data)
        response.raise_for_status()  # Raise an error for bad responses
        answer = response.json()['choices'][0]['message']['content']
        return answer
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as e:
        return f"An error occurred: {e}"

# Reminder storage
reminders = []

# Function to set a reminder
def set_reminder(reminder):
    reminders.append(reminder)
    speak(f"Reminder set for: {reminder}")

# Function to check reminders
def check_reminders():
    if reminders:
        speak("Here are your reminders:")
        for reminder in reminders:
            speak(reminder)
    else:
        speak("You have no reminders.")

# Main loop to listen for commands
while True:
    command = listen_for_commands()
    if command:
        if "hello" in command.lower():
            speak("Hello! I am Jarvis, your personal AI. How can I assist you?")
        elif "time" in command.lower():
            current_time = time.strftime("%H:%M")
            speak(f"The current time is {current_time}.")
        elif "remind me to" in command.lower():
            reminder = command.lower().replace("remind me to", "").strip()
            set_reminder(reminder)
        elif "show reminders" in command.lower():
            check_reminders()
        elif "what is" in command.lower():
            question = command.lower().replace("what is", "").strip()
            answer = ask_question(question)
            speak(answer)
        elif "stop" in command.lower():
            speak("Goodbye! Have a nice day.")
            time.sleep(1)  # Ensure the last message is heard
            break
# Out:
# Listening...
# You said: hello
# Listening...
# You said: time
# Listening...
# You said: what is dog
# Listening...
# You said: stop

# %%
import requests

def web_search(query):
    api_key = os.getenv("AIzaSyBmL73D2QDdlnkrDTzLuMQbbRYGccaIapc")  # Load API key from environment variable
    headers = {
        'Ocp-Apim-Subscription-Key': api_key
    }
    params = {
        'q': query,
        'textDecorations': True,
        'textFormat': 'HTML'
    }
    try:
        response = requests.get('https://api.openai.com/v1/chat/completions', headers=headers, params=params)
        response.raise_for_status()  # Raise an error for bad responses
        search_results = response.json().get('webPages', {}).get('value', [])
        if search_results:
            return search_results[0]['snippet'] + " Read more at: " + search_results[0]['url']
        else:
            return "I couldn't find any results."
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as e:
        return f"An error occurred: {e}"

# Main loop to listen for commands
try:
    while True:
        command = listen_for_commands()
        if command:
            if "hello" in command.lower():
                speak("Hello! I am Jarvis, your personal AI. How can I assist you?")
            elif "time" in command.lower():
                current_time = time.strftime("%H:%M")
                speak(f"The current time is {current_time}.")
            elif "remind me to" in command.lower():
                reminder = command.lower().replace("remind me to", "").strip()
                set_reminder(reminder)
            elif "show reminders" in command.lower():
                check_reminders()
            elif "what is" in command.lower():
                question = command.lower().replace("what is", "").strip()
                answer = ask_question(question)
                speak(answer)
            elif "search for" in command.lower():
                query = command.lower().replace("search for", "").strip()
                search_result = web_search(query)
                speak(search_result)
            elif "stop" in command.lower():
                speak("Goodbye! Have a nice day.")
                time.sleep(1)
                break
except KeyboardInterrupt:
    speak("Shutting down. Goodbye!")
# Out:
# Listening...
# You said: hello hello
# Listening...
# You said: time what's the time
# Listening...
# You said: what is the capital of France
# Listening...
# You said: stop

# %%
import speech_recognition as sr
import pyttsx3
import requests
import time
import os

# Initialize text-to-speech engine
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Listen for commands from the microphone
def listen_for_commands():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio)
            print(f"You said: {command}")
            return command
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            return None
        except sr.RequestError:
            print("Could not request results from Google Speech Recognition service.")
            return None

# Function to perform web search
# Function to perform web search
def web_search(query):
    # Direct answers for known questions
    if query == "capital of india":
        return "The capital of India is New Delhi."

    # Use your Google Custom Search API here for other queries
    api_key = os.getenv("AIzaSyBmL73D2QDdlnkrDTzLuMQbbRYGccaIapc")  # Load API key from environment variable
    url = 'https://www.googleapis.com/customsearch/v1'
    params = {
        'key': api_key,
        'cx': 'YOUR_CUSTOM_SEARCH_ENGINE_ID',  # Replace with your Custom Search Engine ID
        'q': query,
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()  # Raise an error for bad responses
        search_results = response.json().get('items', [])
        if search_results:
            return search_results[0]['snippet'] + " Read more at: " + search_results[0]['link']
        else:
            return "I couldn't find any results."
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as e:
        return f"An error occurred: {e}"

# Reminder storage
reminders = []

# Function to set a reminder
def set_reminder(reminder):
    reminders.append(reminder)
    speak(f"Reminder set for: {reminder}")

# Function to check reminders
def check_reminders():
    if reminders:
        speak("Here are your reminders:")
        for reminder in reminders:
            speak(reminder)
    else:
        speak("You have no reminders.")

# Main loop to listen for commands
try:
    while True:
        command = listen_for_commands()
        if command:
            command = command.lower()  # Normalize command
            if "hello" in command:
                speak("Hello! I am Jarvis, your personal AI. How can I assist you?")
            elif "time" in command:
                current_time = time.strftime("%H:%M")
                speak(f"The current time is {current_time}.")
            elif "remind me to" in command:
                reminder = command.replace("remind me to", "").strip()
                set_reminder(reminder)
            elif "show reminders" in command:
                check_reminders()
            elif "search for" in command:
                query = command.replace("search for", "").strip()
                search_result = web_search(query)
                speak(search_result)
            elif "stop" in command:
                speak("Goodbye! Have a nice day.")
                break
except KeyboardInterrupt:
    speak("Shutting down. Goodbye!")
# Out:
# Listening...
# You said: hello
# Listening...
# You said: search for capital of India
# Listening...
# You said: search for France of India
# Listening...
# You said: 900
# Listening...
# You said: stop

# %%
import speech_recognition as sr
import pyttsx3
import requests
import os

# Initialize text-to-speech engine
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Listen for commands from the microphone
def listen_for_commands():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio)
            print(f"You said: {command}")
            return command.lower()
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            return None
        except sr.RequestError:
            print("Could not request results from Google Speech Recognition service.")
            return None

# Function to perform a web search
def web_search(query):
    api_key = os.getenv("GOOGLE_API_KEY")  # Load your API key from environment variable
    url = 'https://www.googleapis.com/customsearch/v1'
    params = {
        'key': api_key,
        'cx': 'YOUR_CUSTOM_SEARCH_ENGINE_ID',  # Replace with your Custom Search Engine ID
        'q': query,
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        search_results = response.json().get('items', [])
        if search_results:
            return search_results[0]['snippet'] + " Read more at: " + search_results[0]['link']
        else:
            return "I couldn't find any results."
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as e:
        return f"An error occurred: {e}"

# Main loop to listen for commands
try:
    speak("Hello! I am your AI assistant. How can I help you?")
    while True:
        command = listen_for_commands()
        if command:
            if "search for" in command:
                query = command.replace("search for", "").strip()
                search_result = web_search(query)
                speak(search_result)
            elif "stop" in command:
                speak("Goodbye! Have a nice day.")
                break
            else:
                speak("I can only help you search for things on the internet. Try asking me to search for something.")
except Keybo
# Out:
#   Cell In[7], line 68
#     except Keybo
#                 ^
# SyntaxError: expected ':'

# %%
import speech_recognition as sr
import pyttsx3
import requests
import os

# Initialize text-to-speech engine
engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

# Listen for commands from the microphone
def listen_for_commands():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio)
            print(f"You said: {command}")
            return command.lower()
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            return None
        except sr.RequestError:
            print("Could not request results from Google Speech Recognition service.")
            return None

# Function to perform a web search
def web_search(query):
    api_key = os.getenv("AIzaSyBmL73D2QDdlnkrDTzLuMQbbRYGccaIapc")  # Load your API key from environment variable
    url = 'https://www.googleapis.com/customsearch/v1'
    params = {
        'key': api_key,
        'cx': 'YOUR_CUSTOM_SEARCH_ENGINE_ID',  # Replace with your Custom Search Engine ID
        'q': query,
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        search_results = response.json().get('items', [])
        if search_results:
            return search_results[0]['snippet'] + " Read more at: " + search_results[0]['link']
        else:
            return "I couldn't find any results."
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as e:
        return f"An error occurred: {e}"

# Main loop to listen for commands
try:
    speak("Hello! I am your AI assistant. How can I help you?")
    while True:
        command = listen_for_commands()
        if command:
            if "search for" in command:
                query = command.replace("search for", "").strip()
                search_result = web_search(query)
                speak(search_result)
            elif "stop" in command:
                speak("Goodbye! Have a nice day.")
                break
            else:
                speak("I can only help you search for things on the internet. Try asking me to search for something.")
except KeyboardInterrupt:
    speak("Shutting d")
# Out:
# Listening...
# You said: search capital of India search for capital of India
