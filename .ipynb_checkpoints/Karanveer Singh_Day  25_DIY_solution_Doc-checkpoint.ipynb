# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('exam.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group B                 high school  free/reduced
# 1      male        group A          associate's degree      standard
# 2      male        group C            some high school  free/reduced
# 3    female        group D            some high school      standard
# 4    female        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group D                some college      standard
# 996    male        group E             master's degree  free/reduced
# 997  female        group C                some college  free/reduced
# 998  female        group A          associate's degree      standard
# 999  female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
scores = ['math score', 'reading score', 'writing score']

# %%
plt.figure(figsize=(15, 5))

for i, score in enumerate(scores):
    plt.subplot(1, 3, i + 1)
    sns.histplot(df[score], kde=True)
    plt.title(f'Distribution of {score}')
    plt.xlabel(score)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
mean_std_results = {}
for score in scores:
    mean = df[score].mean()
    std = df[score].std()
    mean_std_results[score] = (mean, std)
    print(f'Mean of {score}: {mean:.2f}, Standard Deviation of {score}: {std:.2f}')
# Out:
# Mean of math score: 67.09, Standard Deviation of math score: 14.68
# Mean of reading score: 70.19, Standard Deviation of reading score: 13.82
# Mean of writing score: 68.85, Standard Deviation of writing score: 14.47

# %%
skew_kurt_results = {}
for score in scores:
    skewness = stats.skew(df[score])
    kurtosis = stats.kurtosis(df[score])
    skew_kurt_results[score] = (skewness, kurtosis)
    print(f'Skewness of {score}: {skewness:.2f}, Kurtosis of {score}: {kurtosis:.2f}')
# Out:
# Skewness of math score: -0.25, Kurtosis of math score: 0.03
# Skewness of reading score: -0.20, Kurtosis of reading score: -0.10
# Skewness of writing score: -0.19, Kurtosis of writing score: -0.01

# %%
z_scores = {}
for score in scores:
    z_scores[score] = stats.zscore(df[score])
    df[f'z_{score}'] = z_scores[score]

# %%
plt.figure(figsize=(15, 5))

for i, score in enumerate(scores):
    plt.subplot(1, 3, i + 1)
    sns.histplot(df[f'z_{score}'], kde=True)
    plt.title(f'Z-Distribution of {score}')
    plt.xlabel(f'z_{score}')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
